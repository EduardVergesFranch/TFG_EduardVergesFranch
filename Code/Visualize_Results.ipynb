# %%
import sys
sys.path.append('../')

# %%
from IPython.display import display, Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from test_pipeline_tools.Visualize_Results import Visualize_Results

# %% [markdown]
# # Change fields to filter the results

# %%
VR = Visualize_Results(images_path = '../RESULTS/cross-validation/fold_plots/')

# %%
dabase_names = ['Raw_database',
                'MeldaProduction_Rooms',
                'MIT_Reverbs',
                'MeldaProduction_Microphones',
                'MeldaProduction_Box',
                'AllurePack',
                'SOX_Effects',
                'SOX_Filters']

database = dabase_names[0]
split = '0'
kind = 'min'

# %% [markdown]
# # Visualization

# %%
VR.overall_accuracies(database)

# %%
VR.result(database,split)

# %%
VR.filtered_stats(database,'+3', split)
